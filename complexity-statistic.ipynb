# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dữ liệu
X1 = 2.739205
X2 = 1.288835
X3 = 6.4691
X4 = 4.311655

Y1 = 49.45
Y2 = 387.6
Y3 = 90
Y4 = 75.3

data = {
    'Thuật toán': ['BFS', 'DFS', 'A*', 'A* Cải tiến'],
    'Thời gian (ms)': [X1, X2, X3, X4],
    'Không gian (nodes)': [Y1, Y2, Y3, Y4]
}

# Tạo DataFrame từ dữ liệu
df = pd.DataFrame(data)

# In bảng dữ liệu
print("Bảng dữ liệu gốc:")
print(df)

# Tạo 2 hình riêng biệt
fig, ax = plt.subplots(figsize=(8, 6))

# Biểu đồ thời gian
ax.bar(df['Thuật toán'], df['Thời gian (ms)'], color='skyblue')
ax.set_title('Thời gian thực thi (ms)')
ax.set_xlabel('Thuật toán')
ax.set_ylabel('Thời gian (ms)')

# Thêm ghi chú vào biểu đồ thời gian
for bar in ax.patches:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Tạo hình thứ 2 cho không gian
fig, ax = plt.subplots(figsize=(8, 6))

# Biểu đồ không gian
ax.bar(df['Thuật toán'], df['Không gian (nodes)'], color='lightgreen')
ax.set_title('Không gian lưu trữ (nodes)')
ax.set_xlabel('Thuật toán')
ax.set_ylabel('Không gian (nodes)')

# Thêm ghi chú vào biểu đồ không gian
for bar in ax.patches:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# Bảng dữ liệu gốc:
#     Thuật toán  Thời gian (ms)  Không gian (nodes)
# 0          BFS        2.739205               49.45
# 1          DFS        1.288835              387.60
# 2           A*        6.469100               90.00
# 3  A* Cải tiến        4.311655               75.30
